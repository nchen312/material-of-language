# %%
import random
import math

# %%
from IPython.display import display, HTML
def show_html(src):
    return display(HTML(src), metadata=dict(isolated=True))

# %%
html_tmpl = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="utf-8">
    <title>{title}</title>
    <style>
    html {{ min-height: 32em; overflow: hidden; }}
    <link href="https://fonts.googleapis.com/css?family=Noto+Serif+SC&display=swap" rel="stylesheet">
    </style>
</head>
<body>
{content}
</body>
</html>"""

# %%
def mkdiv(content, **kwargs):
    if 'position' not in kwargs:
        kwargs['position'] = 'absolute'
    style_str = ' '.join([": ".join((k.replace('_', '-'), v))+";" for k, v in kwargs.items()])
    return f"<div style='{style_str}'>{content}</div>"

# %%
grid_size = 12
divs = []
for i in range(grid_size):
    for j in range(grid_size):
        x_pos = 25 + (30 / grid_size) * i
        y_pos = 25 + (30 / grid_size) * j
        size = j
        this_div = mkdiv("木",
                        left=f"{x_pos}%",
                        top=f"{y_pos}%",
                         transform="translate(-50%, -50%)",
                        font_size=f"{size}pt")
        divs.append(this_div)
html_src = html_tmpl.format(title="木", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>木</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     <link href="https://fonts.googleapis.com/css?family=Noto+Serif+SC&display=swap" rel="stylesheet">
#     </style>
# </head>
# <body>
# ...

# %%
grid_size = 12
divs = []
for i in range(grid_size):
    for j in range(grid_size):
        x_pos = 25 + (50 / grid_size) * i
        y_pos = 25 + (70 / grid_size) * j
        size = j*2
        this_div = mkdiv("土",
                        left=f"{x_pos}%",
                        top=f"{y_pos}%",
                         transform="translate(-50%, -50%)",
                        font_size=f"{size}pt")
        divs.append(this_div)
html_src = html_tmpl.format(title="土", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>土</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     <link href="https://fonts.googleapis.com/css?family=Noto+Serif+SC&display=swap" rel="stylesheet">
#     </style>
# </head>
# <body>
# ...

# %%
grid_size = 12
divs = []
for i in range(grid_size):
    for j in range(grid_size):
        x_pos = 25 + (50 / grid_size) * i
        y_pos = 25 + (60 / grid_size) * j
        size = 20
        this_div = mkdiv("口",
                        left=f"{x_pos}%",
                        top=f"{y_pos}%",
                         transform="translate(-50%, -50%)",
                        font_size=f"{size}pt")
        divs.append(this_div)
html_src = html_tmpl.format(title="口", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>口</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     <link href="https://fonts.googleapis.com/css?family=Noto+Serif+SC&display=swap" rel="stylesheet">
#     </style>
# </head>
# <body>
# ...

# %%
grid_size = 12
divs = []
for i in range(grid_size):
    for j in range(grid_size):
        x_pos = 25 + (50 / grid_size) * i
        y_pos = 25 + (60 / grid_size) * j
        size = 20
        this_div = mkdiv("口",
                        left=f"{x_pos}%",
                        top=f"{y_pos}%",
                         transform="translate(-50%, -50%)",
                        font_size=f"{size}pt")
        divs.append(this_div)
        that_div=mkdiv("口",
                        left=f"{x_pos}%",
                        top=f"{y_pos}%",
                        transform="translate(-50%, -50%)",                       
                        font_size=f"{size/2.5}pt")
        divs.append(that_div)
html_src = html_tmpl.format(title="回", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>回</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     <link href="https://fonts.googleapis.com/css?family=Noto+Serif+SC&display=swap" rel="stylesheet">
#     </style>
# </head>
# <body>
# ...

# %%
grid_size = 12
divs = []
for i in range(grid_size):
    for j in range(grid_size):
        x_pos = 25 + (50 / grid_size) * i
        if j%2==0:
            y_pos = 25 + (60 / grid_size) * j+2
        else:
            y_pos = 25 + (60 / grid_size) * j
        size = 20
        this_div = mkdiv("口",
                        left=f"{x_pos}%",
                        top=f"{y_pos}%",
                         transform="translate(-50%, -50%)",
                        font_size=f"{size}pt")
        divs.append(this_div)
html_src = html_tmpl.format(title="日", content="".join(divs))
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>日</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     <link href="https://fonts.googleapis.com/css?family=Noto+Serif+SC&display=swap" rel="stylesheet">
#     </style>
# </head>
# <body>
# ...

# %%
grid_size = 12
divs = []
for i in range(grid_size):
    for j in range(grid_size):
        x_pos = 25 + (50 / grid_size) * i
        if j%2==0:
            y_pos = 25 + (60 / grid_size) * j+3.5
        else:
            y_pos = 25 + (60 / grid_size) * j
        size = 20
        this_div = mkdiv("口",
                        left=f"{x_pos}%",
                        top=f"{y_pos}%",
                         transform="translate(-50%, -50%)",
                        font_size=f"{size}pt")
        divs.append(this_div)
html_src = html_tmpl.format(title="目", content="".join(divs))

show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>目</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     <link href="https://fonts.googleapis.com/css?family=Noto+Serif+SC&display=swap" rel="stylesheet">
#     </style>
# </head>
# <body>
# ...

# %%
grid_size = 12
divs = []
for i in range(grid_size):
    for j in range(grid_size):
        x_pos = 25 + (50 / grid_size) * i
        size = 20
        if j%2==0:
            y_pos = 25 + (60 / grid_size) * j
            this_div = mkdiv("口",
                        left=f"{x_pos}%",
                        top=f"{y_pos}%",
                        transform="translate(-50%, -50%)",
                        font_size=f"{size/2}pt")
            divs.append(this_div)
        else:
            y_pos = 25 + (60 / grid_size) * j-2
            this_div = mkdiv("口",
                        left=f"{x_pos}%",
                        top=f"{y_pos}%",
                        transform="translate(-50%, -50%)",
                        font_size=f"{size}pt")
        divs.append(this_div)
html_src = html_tmpl.format(title="吕", content="".join(divs))

show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>吕</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     <link href="https://fonts.googleapis.com/css?family=Noto+Serif+SC&display=swap" rel="stylesheet">
#     </style>
# </head>
# <body>
# ...

# %%
grid_size = 12
divs = []
for i in range(grid_size):
    for j in range(grid_size):
        if i%2==0:
            x_pos = 25 + (50 / grid_size) * i
        else:
            x_pos = 25 + (50 / grid_size) * i-3.2
        if j%2==0:
            y_pos = 25 + (50 / grid_size) * j+2
        else:
            y_pos = 25 + (50 / grid_size) * j
        size = 20
        this_div = mkdiv("口",
                        left=f"{x_pos}%",
                        top=f"{y_pos}%",
                         transform="translate(-50%, -50%)",
                        font_size=f"{size/1.5}pt")
        divs.append(this_div)
html_src = html_tmpl.format(title="田", content="".join(divs))

show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>田</title>
#     <style>
#     html { min-height: 32em; overflow: hidden; }
#     <link href="https://fonts.googleapis.com/css?family=Noto+Serif+SC&display=swap" rel="stylesheet">
#     </style>
# </head>
# <body>
# ...
